# %%
run_id = 'crawl_test_b'
time_stamp = '20251119_173549'
path = f'../data/meta/class_performance/{run_id}/{run_id}_class_performance_{time_stamp}.csv'

# !ls {path}
# Out:
# ../data/meta/class_performance/crawl_test_b/crawl_test_b_class_performance_20251119_173549.csv

# %%
import pandas as pd
df = pd.read_csv(path)
df.head()
# Out:
#          run_id folder  class_id class_name  total_images  \
# 0  crawl_test_b     국밥         0         국밥             5
# 1  crawl_test_b   삼각김밥         7       삼각김밥             5
#
#    images_with_detections  images_without_detections  detections  \
# 0                       5                          0          23
# 1                       3                          2          10
#
#    avg_confidence  min_confidence  max_confidence  low_conf_detections  \
# 0          0.7787          0.4291          0.9626                    0
# 1          0.5992          0.4001          0.7618                    0
#
#    low_conf_ratio  review_images top_review_reasons
# 0             0.0              0                NaN
# 1             0.0              2    no_detections:4
